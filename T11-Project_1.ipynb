# %% [markdown]
# # Analyzing Flight Price Differences

# %% [markdown]
# T11: Hanze Zhang (hanzez) & Yi-Hsueh Yang (yihsuehy)
# Video Link: https://cmu.zoom.us/rec/share/maqX_iARNdnfQelFxzxco8NExJi8CNjE1RlKLdsLWofaf0byKxHSDI0n2wdQS9UI.2kuXCz4kN7ZfsaA_?startTime=1679015619000
# Passcode: 8FTg?#1p
#
# Data Source: https://github.com/dilwong/FlightPrices
#
# https://www.kaggle.com/datasets/dilwong/flightprices

# %%
# These two chunks are meant to import data from kaggle, due to its enormous size we choose this import method to relax the loading pressure for our local machines.
'''! pip install -q kaggle
from google.colab import files
files.upload()'''

# %%
 '''! mkdir ~/.kaggle
 ! cp kaggle.json ~/.kaggle/
 ! chmod 600 ~/.kaggle/kaggle.json
 ! kaggle datasets list
 # !kaggle datasets download -d dilwong/flightprices
 # !unzip flightprices.zip'''

# %%
import pandas as pd
import altair as alt
import datetime
import re

# Disable max row limitation by Altair
alt.data_transformers.disable_max_rows()
# Disable limitation on the width of dataframe columns
pd.set_option('display.max_colwidth', None)

# %%
# mount google drive to load in data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# In this block of code, we are dealing with the size of our original dataset. It is a huge dataset with 30G+ of data, so we break it into smaller chunks of datasets by filtering out some unnecessary columns and limit the time duration to around 1 and a half month per dataset.

# %%
'''chunksize = 1000

# Specify the columns to read from the CSV file
columns = ['searchDate', 'flightDate', 'startingAirport', 'destinationAirport', 'fareBasisCode', 'travelDuration', 
           'elapsedDays', 'isBasicEconomy', 'isRefundable', 'isNonStop', 'baseFare', 'totalFare', 'seatsRemaining', 
           'totalTravelDistance', 'segmentsDepartureTimeRaw', 'segmentsAirlineCode', 'segmentsEquipmentDescription','segmentsCabinCode']

column2 = ['searchDate', 'flightDate', 'totalFare']

# Create an empty list to store the filtered chunks
filtered_chunks = []

# Loop through the CSV file in chunks
for chunk in pd.read_csv('itineraries.csv', chunksize=chunksize, usecols=column2):
    # Filter the chunk based on a condition
    filtered_chunk = chunk[chunk['flightDate'] >= '2022-09-15']

    # Append the filtered chunk to the list
    filtered_chunks.append(filtered_chunk)

# Concatenate the filtered chunks into a single DataFrame
filtered_df = pd.concat(filtered_chunks)

filtered_df = pd.read_csv('itineraries.csv', usecols=column2)

# save the filtered data to a csv file
filtered_df.to_csv('/content/drive/My Drive/Alltime_Data.csv', index=False)

print(filtered_df.shape)'''

# %% [markdown]
# ## Analysis Starts Here

# %%
april_may_df = pd.read_csv('drive/My Drive/Data_Science_Big_Data_T11/April_May_Data.csv')
april_may_df = april_may_df.drop(['segmentsEquipmentDescription', 
                                  'elapsedDays', 'baseFare'], axis=1)

april_may_df.head(10)
# Out:
#    searchDate  flightDate startingAirport destinationAirport fareBasisCode  \
# 0  2022-04-16  2022-04-17             ATL                BOS      LA0NX0MC
# 1  2022-04-16  2022-04-17             ATL                BOS      LA0NX0MC
# 2  2022-04-16  2022-04-17             ATL                BOS      LA0NX0MC
# 3  2022-04-16  2022-04-17             ATL                BOS      LA0NX0MC
# 4  2022-04-16  2022-04-17             ATL                BOS      LA0NX0MC
# 5  2022-04-16  2022-04-17             ATL                BOS      VH0AUEL1
# 6  2022-04-16  2022-04-17             ATL                BOS      V0AJZNN1
# 7  2022-04-16  2022-04-17             ATL                BOS      V0AJZNN1
# 8  2022-04-16  2022-04-17             ATL                BOS      V0AJZNN1
# 9  2022-04-16  2022-04-17             ATL                BOS      V0AJZNN1
#
#   travelDuration  isBasicEconomy  isRefundable  isNonStop  totalFare  \
# 0        PT2H29M           False         False       True      248.6
# 1        PT2H30M           False         False       True      248.6
# 2        PT2H30M           False         False       True      248.6
# 3        PT2H32M           False         False       True      248.6
# 4        PT2H34M           False         False       True      248.6
# 5        PT2H38M           False         False       True      248.6
# 6        PT4H12M           False         False      False      251.1
# 7        PT5H18M           False         False      False      251.1
# 8        PT5H32M           False         False      False      251.1
# 9        PT6H38M           False         False      False      251.1
#
#    seatsRemaining  totalTravelDistance  \
# 0               9                947.0
# 1               4                947.0
# 2               9                947.0
# 3               8                947.0
# 4               9                947.0
# 5               7                947.0
# 6               3                956.0
# 7               3                956.0
# 8               7                956.0
# 9               7                956.0
#
#                                        segmentsDepartureTimeRaw  \
# 0                                 2022-04-17T12:57:00.000-04:00
# 1                                 2022-04-17T06:30:00.000-04:00
# 2                                 2022-04-17T11:35:00.000-04:00
# 3                                 2022-04-17T13:59:00.000-04:00
# 4                                 2022-04-17T09:59:00.000-04:00
# 5                                 2022-04-17T10:45:00.000-04:00
# 6  2022-04-17T08:20:00.000-04:00||2022-04-17T10:27:00.000-04:00
# 7  2022-04-17T08:20:00.000-04:00||2022-04-17T11:20:00.000-04:00
# 8  2022-04-17T07:00:00.000-04:00||2022-04-17T10:27:00.000-04:00
# 9  2022-04-17T07:00:00.000-04:00||2022-04-17T11:20:00.000-04:00
#
#   segmentsAirlineCode segmentsCabinCode
# 0                  DL             coach
# 1                  DL             coach
# 2                  DL             coach
# 3                  DL             coach
# 4                  DL             coach
# 5                  B6             coach
# 6              AA||AA      coach||coach
# 7              AA||AA      coach||coach
# 8              AA||AA      coach||coach
# 9              AA||AA      coach||coach

# %%
def to_time(date_time):
    return '||'.join([pd.to_datetime(date).strftime('%H:%M:%S') for date in date_time.split('||')])
april_may_df['departure_time'] = april_may_df['segmentsDepartureTimeRaw'].apply(lambda x : to_time(x))
april_may_df = april_may_df.drop('segmentsDepartureTimeRaw', axis = 1)

# %% [markdown]
# 1. Compare Mean flight price in different date
# 2. Compare Mean flight price in different days in a week
# 3. Compare mean flight price in times in a day
# 4. compare flight price between airports in the same city
# 5. the relationship between price and the remaining seats of the same flight

# %% [markdown]
# # Compare Mean flight price in different days in a week

# %%
df = april_may_df.copy()

df['flightDate'] = pd.to_datetime(df['flightDate'])
df['searchDate'] = pd.to_datetime(df['searchDate'])

date_to_fare = pd.DataFrame(df.groupby('flightDate')['totalFare'].mean().reset_index())

# %%
df['daysinweek'] = df['flightDate'].apply(lambda x: x.date().weekday())
df['search_daysinweek'] = df['searchDate'].apply(lambda x: x.date().weekday())

daysinweek_to_fare = pd.DataFrame(df.groupby('daysinweek')['totalFare'].mean().reset_index())
search_daysinweek_to_fare = pd.DataFrame(df.groupby('search_daysinweek')['totalFare'].mean().reset_index())

daysinweek_to_fare['type'] = ['schedule','schedule','schedule','schedule','schedule','schedule','schedule' ]
search_daysinweek_to_fare['type'] = ['search','search','search','search','search','search','search' ]

search_and_flight = pd.concat([search_daysinweek_to_fare, daysinweek_to_fare])

weekday_mapping = {0: 'Mon', 1: 'Tue', 2: 'Wed', 3: 'Thu', 4: 'Fri', 5: 'Sat', 6: 'Sun'}
search_and_flight['weekday'] = daysinweek_to_fare['daysinweek'].map(weekday_mapping)

search_and_flight
# Out:
#    search_daysinweek   totalFare      type  daysinweek weekday
# 0                0.0  348.536190    search         NaN     Mon
# 1                1.0  356.954535    search         NaN     Tue
# 2                2.0  358.033568    search         NaN     Wed
# 3                3.0  359.098796    search         NaN     Thu
# 4                4.0  354.752974    search         NaN     Fri
# 5                5.0  356.717495    search         NaN     Sat
# 6                6.0  345.487025    search         NaN     Sun
# 0                NaN  373.910616  schedule         0.0     Mon
# 1                NaN  306.309631  schedule         1.0     Tue
# 2                NaN  310.695726  schedule         2.0     Wed
# 3                NaN  372.045373  schedule         3.0     Thu
# 4                NaN  376.048031  schedule         4.0     Fri
# 5                NaN  335.517184  schedule         5.0     Sat
# 6                NaN  420.651045  schedule         6.0     Sun

# %%
#0: Monday, 6: Sunday

alt.Chart(search_and_flight).mark_line().transform_fold(
    fold=['search', 'schedule'], 
).encode(
    x=alt.X('weekday:N', sort=['Mon','Tue','Wed','Thu','Fri','Sat','Sun']),
    y='totalFare:Q',
    color='type'
).properties(
    title = 'Mean Flight Price and Search Flight Price by day of week'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# # Compare flight price between airports in the same city

# %% [markdown]
# Airports:
#  DFW, DEN, ORD, LAX, CLT, MIA, JFK, EWR, SFO, DTW, BOS, PHL, LGA, IAD, OAK
# *   ATL: Hartsfield-Jackson Atlanta International Airport
# *   DFW: Dallas/Fort Worth International Airport
# *   ORD: Chicago O'Hare International Airport
# *   LAX: Los Angeles International Airport
# *   CLT: Charlotte Douglas International Airport
# *   MIA: Miami International Airport
# *   JFK: John F. Kennedy International Airport (New York)
# *   EWR: Newark Liberty International Airport (New York and New Jersey)
# *   SFO: San Francisco International Airport
# *   DTW: Detroit Metropolitan Wayne County Airport
# *   BOS: Boston Logan International Airport
# *   PHL: Philadelphia International Airport
# *   LGA: LaGuardia Airport (New York)
# *   IAD: Dulles International Airport
# *   OAK: Oakland International Airport
#
# Airports around New York City: JFK, EWR, LGA
# Airports around San Francisco: OAK, SFO

# %%
# Filter out every tickets that flight to airports around NYC
new_york_df = april_may_df[(april_may_df['destinationAirport'] == 'JFK') | 
                           (april_may_df['destinationAirport'] == 'EWR') | 
                           (april_may_df['destinationAirport'] == 'LGA')].copy()

# Filter out every tickets that flight to airports around San Francisco
sf_df = april_may_df[(april_may_df['destinationAirport'] == 'OAK') | 
                     (april_may_df['destinationAirport'] == 'SFO')].copy()

# %%
# Parse travelDuration
def parse_duration(str_duration):
    '''
        Convert the given string which contains the number of hours and minutes
        to a single float representing the number of hours of the flight.
    '''
    hour = 0
    minute = 0

    # Extract number from string through regular expression
    hour_minute = [(int) (digit) for digit in re.findall(r'\d+', str_duration)]

    if 'DT' in str_duration:
        # If day time is specified
        hour += 24 * hour_minute.pop(0)
        
    if 'H' in str_duration and 'M' in str_duration:
        # Both hour and minute are specified
        hour += hour_minute[0]
        minute = hour_minute[1]
    elif 'H' in str_duration:
        # Only hour is specified
        hour = hour_minute[0]
    else:
        # Only minute is specified
        minute = hour_minute[0]
    
    return hour + minute / 60

# Apply the transformation on new york df and append a new column
new_york_df['parsed_duration'] = new_york_df['travelDuration'].apply(
                                    lambda x : parse_duration(x)
                                 )
new_york_df.drop('travelDuration', axis=1) # drop the old travel duration

# Apply the same transformation on sf df
sf_df['parsed_duration'] = sf_df['travelDuration'].apply(
                                    lambda x : parse_duration(x)
                                 )
sf_df.drop('travelDuration', axis=1) # drop the old travel duration
# Out:
#          searchDate  flightDate startingAirport destinationAirport  \
# 431      2022-04-16  2022-04-17             ATL                OAK
# 432      2022-04-16  2022-04-17             ATL                OAK
# 433      2022-04-16  2022-04-17             ATL                OAK
# 434      2022-04-16  2022-04-17             ATL                OAK
# 435      2022-04-16  2022-04-17             ATL                OAK
# ...             ...         ...             ...                ...
# 5932489  2022-05-06  2022-05-09             JFK                SFO
# 5932490  2022-05-06  2022-05-09             JFK                SFO
# 5932491  2022-05-06  2022-05-09             JFK                SFO
# 5932492  2022-05-06  2022-05-09             JFK                SFO
# 5932493  2022-05-06  2022-05-09             JFK                SFO
#
#         fareBasisCode  isBasicEconomy  isRefundable  isNonStop  totalFare  \
# 431            Y0CXHO           False         False      False     463.58
# 432            Y0CXHO           False         False      False     463.58
# 433          HA0OA0MC           False         False      False     477.61
# 434          HA0OA0MC           False         False      False     477.61
# 435            Y0CXHO           False         False      False     510.07
# ...               ...             ...           ...        ...        ...
# 5932489      KH0JUEL1           False         False       True     578.60
# 5932490      YH0JUEY5           False         False       True     713.60
# 5932491      YH0JUEY5           False         False       True     713.60
# 5932492      YH0JUEY5           False         False       True     713.60
# 5932493           Y0N           False         False       True     998.60
#
#          seatsRemaining  totalTravelDistance  \
# 431                   0                  NaN
# 432                   0                  NaN
# 433                   1               2175.0
# 434                   1               2175.0
# 435                   0                  NaN
# ...                 ...                  ...
# 5932489               7               2566.0
# 5932490               7               2566.0
# 5932491               7               2566.0
# 5932492               7               2566.0
# 5932493               9               2566.0
#
#                                                                             segmentsDepartureTimeRaw  \
# 431                                     2022-04-17T21:24:00.000-04:00||2022-04-18T08:45:00.000-07:00
# 432                                     2022-04-17T06:35:00.000-04:00||2022-04-17T19:49:00.000-07:00
# 433                                     2022-04-17T19:36:00.000-04:00||2022-04-17T22:59:00.000-06:00
# 434                                     2022-04-17T08:10:00.000-04:00||2022-04-17T11:50:00.000-06:00
# 435      2022-04-17T19:42:00.000-04:00||2022-04-17T22:40:00.000-04:00||2022-04-18T08:45:00.000-07:00
# ...                                                                                              ...
# 5932489                                                                2022-05-09T12:00:00.000-04:00
# 5932490                                                                2022-05-09T06:55:00.000-04:00
# 5932491                                                                2022-05-09T12:00:00.000-04:00
# 5932492                                                                2022-05-09T09:30:00.000-04:00
# 5932493                                                                2022-05-09T11:10:00.000-04:00
#
#         segmentsAirlineCode    segmentsCabinCode  parsed_duration
# 431                  NK||NK         coach||coach        15.833333
# 432                  NK||NK         coach||coach        17.550000
# 433                  DL||DL         coach||coach         7.350000
# 434                  DL||DL         coach||coach         7.633333
# 435              NK||NK||NK  coach||coach||coach        17.533333
# ...                     ...                  ...              ...
# 5932489                  B6                coach         6.466667
# 5932490                  AA                coach         6.350000
# 5932491                  AA                coach         6.466667
# 5932492                  AA                coach         6.500000
# 5932493                  DL                coach         6.500000
#
# [617913 rows x 15 columns]

# %%
# aggregate by starting airport and destination airport to 
# calculated mean total price and flight duration 
aggregated_ny_df = new_york_df.groupby(
    by=['startingAirport', 'destinationAirport']
    )[['totalFare', 'parsed_duration']].mean().reset_index()
aggregated_ny_df
# Out:
#    startingAirport destinationAirport   totalFare  parsed_duration
# 0              ATL                EWR  243.334567         4.691515
# 1              ATL                JFK  308.677985         5.483164
# 2              ATL                LGA  220.564771         4.542456
# 3              BOS                EWR  177.024419         4.130699
# 4              BOS                JFK  178.089606         2.229200
# 5              BOS                LGA  143.624904         3.166926
# 6              CLT                EWR  252.648955         4.142739
# 7              CLT                JFK  280.823552         4.965108
# 8              CLT                LGA  213.972333         3.855167
# 9              DEN                EWR  348.564513         6.745136
# 10             DEN                JFK  493.807953         9.136086
# 11             DEN                LGA  269.895516         6.394817
# 12             DFW                EWR  320.660045         6.011525
# 13             DFW                JFK  355.799888         6.434271
# 14             DFW                LGA  241.745208         5.393389
# 15             DTW                EWR  267.829216         5.596520
# 16             DTW                JFK  384.810786         6.462211
# 17             DTW                LGA  210.565128         4.165532
# 18             IAD                EWR  309.727726         5.539982
# 19             IAD                JFK  382.795948         7.302543
# 20             IAD                LGA  386.967058         6.471922
# 21             LAX                EWR  452.136409         8.389895
# 22             LAX                JFK  443.865091         7.591866
# 23             LAX                LGA  438.874818         9.247198
# 24             MIA                EWR  264.820759         4.986164
# 25             MIA                JFK  239.780051         3.908994
# 26             MIA                LGA  220.121607         4.918455
# 27             OAK                EWR  566.234921        11.998450
# 28             OAK                JFK  550.595470        10.820000
# 29             OAK                LGA  698.285556        14.039015
# 30             ORD                EWR  232.601681         4.211705
# 31             ORD                JFK  403.889820         6.176778
# 32             ORD                LGA  182.040689         3.518558
# 33             PHL                EWR  386.063914         7.119851
# 34             PHL                JFK  344.472884         6.146404
# 35             PHL                LGA  319.525041         7.228287
# 36             SFO                EWR  511.403722         8.391853
# 37             SFO                JFK  444.887516         6.883112
# 38             SFO                LGA  540.555865        10.128277

# %%
# aggregate by starting airport and destination airport to 
# calculated mean total price and flight duration 
aggregated_sf_df = sf_df.groupby(
    by=['startingAirport', 'destinationAirport']
    )[['totalFare', 'parsed_duration']].mean().reset_index()
aggregated_sf_df
# Out:
#    startingAirport destinationAirport   totalFare  parsed_duration
# 0              ATL                OAK  630.816023        12.152037
# 1              ATL                SFO  554.468680        10.021577
# 2              BOS                OAK  601.611038        12.810557
# 3              BOS                SFO  451.750279         9.654979
# 4              CLT                OAK  664.895833        12.809369
# 5              CLT                SFO  577.048896        10.281290
# 6              DEN                OAK  387.694764         7.889882
# 7              DEN                SFO  337.759894         5.679192
# 8              DFW                OAK  480.466269        10.988052
# 9              DFW                SFO  434.044436         7.467747
# 10             DTW                OAK  579.233959        12.344623
# 11             DTW                SFO  578.484447         9.869453
# 12             EWR                OAK  564.880467        12.588182
# 13             EWR                SFO  458.815619         8.817014
# 14             IAD                OAK  665.276289        13.698998
# 15             IAD                SFO  543.897274         9.603450
# 16             JFK                OAK  537.001404        11.093392
# 17             JFK                SFO  427.004426         7.868897
# 18             LAX                OAK  365.931278         7.838249
# 19             LAX                SFO  195.636777         2.330747
# 20             LGA                OAK  715.005921        14.349343
# 21             LGA                SFO  533.073169        10.817695
# 22             MIA                OAK  687.193471        13.982645
# 23             MIA                SFO  530.065832        11.626976
# 24             OAK                SFO  410.529886         7.471527
# 25             ORD                OAK  505.421250        10.672869
# 26             ORD                SFO  486.800258         7.965501
# 27             PHL                OAK  640.992964        13.406333
# 28             PHL                SFO  569.817979        10.507860
# 29             SFO                OAK  426.502131         7.191254

# %%
# Plot to see the relationship between travel duration and total fair flying to
# different airports around New York City
alt.Chart(aggregated_ny_df).mark_point().encode(
    y=alt.Y('totalFare', title='Average Total Fare'),
    x='parsed_duration',
    color='destinationAirport',
    facet=alt.Facet('startingAirport:N', columns=5)
).properties(
    width=100,
    height=100,
    title='Travel Duration to Average Total Fare (All flights to NYC)'
)
# Out:
# alt.Chart(...)

# %%
# One interesting thing here is that even though OAK is more eastern, it has longer average flight duraition than SFO.
# try to see if this is due to the lack of direct flight from OAK to EWR/JFK/LGA
oak_total = len(new_york_df[new_york_df['startingAirport'] == 'OAK'])
print('Total flight from OAK to EWR/JFK/LGA): ', oak_total)
oak_non_direct_num = len(new_york_df[(new_york_df['startingAirport'] == 'OAK') & (new_york_df['isNonStop'] == False)])
print('Number of non-direct flight from OAK to EWR/JFK/LGA): ', oak_non_direct_num)
print('Percentage of non-direct flight from OAK to EWR/JFK/LGA: ', oak_non_direct_num / oak_total) 

print()

sfo_total = len(new_york_df[new_york_df['startingAirport'] == 'SFO'])
print('Total flight from SFO to EWR/JFK/LGA): ', sfo_total)
sfo_non_direct_num = len(new_york_df[(new_york_df['startingAirport'] == 'SFO') & (new_york_df['isNonStop'] == False)])
print('Number of non-direct flight from SFO to EWR/JFK/LGA): ', sfo_non_direct_num)
print('Percentage of non-direct flight from SFO to EWR/JFK/LGA: ', sfo_non_direct_num / sfo_total)
# Out:
# Total flight from OAK to EWR/JFK/LGA):  49063
# Number of non-direct flight from OAK to EWR/JFK/LGA):  49063
# Percentage of non-direct flight from OAK to EWR/JFK/LGA:  1.0
#
# Total flight from SFO to EWR/JFK/LGA):  92504
# Number of non-direct flight from SFO to EWR/JFK/LGA):  65024
# Percentage of non-direct flight from SFO to EWR/JFK/LGA:  0.7029317651128599

# %%
# Direct Flight
aggregated_direct_ny_df = new_york_df[new_york_df['isNonStop'] == True].groupby(
    by=['startingAirport', 'destinationAirport']
    )[['totalFare', 'parsed_duration']].mean().reset_index()
aggregated_direct_ny_df
# Out:
#    startingAirport destinationAirport   totalFare  parsed_duration
# 0              ATL                EWR  236.953722         2.238933
# 1              ATL                JFK  237.783008         2.319009
# 2              ATL                LGA  212.675294         2.302972
# 3              BOS                EWR  122.537929         1.488253
# 4              BOS                JFK  140.218420         1.368825
# 5              BOS                LGA   98.987157         1.403900
# 6              CLT                EWR  228.132007         1.896095
# 7              CLT                JFK  249.472971         1.991044
# 8              CLT                LGA  231.092081         1.814889
# 9              DEN                EWR  340.406978         3.728489
# 10             DEN                JFK  239.344630         3.837255
# 11             DEN                LGA  243.787792         3.727296
# 12             DFW                EWR  274.520259         3.481900
# 13             DFW                JFK  262.503864         3.668959
# 14             DFW                LGA  219.843050         3.447294
# 15             DTW                EWR  217.931319         1.764418
# 16             DTW                JFK  252.983367         1.809917
# 17             DTW                LGA  194.795426         1.790475
# 18             IAD                EWR  245.125173         1.373299
# 19             IAD                JFK  208.812207         1.405006
# 20             IAD                LGA  174.769978         1.409572
# 21             LAX                EWR  464.727301         5.315765
# 22             LAX                JFK  450.952115         5.512284
# 23             LAX                LGA  302.004894         5.218085
# 24             MIA                EWR  214.639914         3.062954
# 25             MIA                JFK  194.359368         3.027458
# 26             MIA                LGA  199.905787         3.003094
# 27             ORD                EWR  203.748012         2.172070
# 28             ORD                JFK  191.484955         2.348316
# 29             ORD                LGA  178.286317         2.142776
# 30             PHL                EWR  255.155243         0.793467
# 31             SFO                EWR  483.905711         5.531966
# 32             SFO                JFK  445.958103         5.707199

# %%
alt.Chart(aggregated_direct_ny_df).mark_point().encode(
    y=alt.Y('totalFare', title='Average Total Fare'),
    x='parsed_duration',
    color='destinationAirport',
    facet=alt.Facet('startingAirport:N', columns=5)
).properties(
    width=100,
    height=100,
    title='Travel Duration to Average Total Fare (Direct flights to NYC)'
)
# Out:
# alt.Chart(...)

# %%
# Non Direct flight
aggregated_transfer_ny_df = new_york_df[new_york_df['isNonStop'] == False].groupby(
    by=['startingAirport', 'destinationAirport']
    )[['totalFare', 'parsed_duration']].mean().reset_index()
aggregated_transfer_ny_df
# Out:
#    startingAirport destinationAirport   totalFare  parsed_duration
# 0              ATL                EWR  249.848491         7.195248
# 1              ATL                JFK  354.129617         7.511743
# 2              ATL                LGA  227.392428         6.480536
# 3              BOS                EWR  263.105431         8.305392
# 4              BOS                JFK  392.813183         7.107390
# 5              BOS                LGA  218.860516         6.138456
# 6              CLT                EWR  277.693013         6.437684
# 7              CLT                JFK  299.654491         6.751499
# 8              CLT                LGA  199.431296         5.588122
# 9              DEN                EWR  351.343077         7.772645
# 10             DEN                JFK  526.380109         9.814355
# 11             DEN                LGA  284.019394         7.837904
# 12             DFW                EWR  345.198452         7.356848
# 13             DFW                JFK  409.195414         8.016924
# 14             DFW                LGA  264.881824         7.449171
# 15             DTW                EWR  291.463942         7.411640
# 16             DTW                JFK  438.675299         8.363132
# 17             DTW                LGA  221.299950         5.782291
# 18             IAD                EWR  328.296425         6.737611
# 19             IAD                JFK  406.221178         8.096589
# 20             IAD                LGA  430.725212         7.515853
# 21             LAX                EWR  448.098123         9.375863
# 22             LAX                JFK  436.349401         9.797233
# 23             LAX                LGA  439.127143         9.254626
# 24             MIA                EWR  320.227894         7.109675
# 25             MIA                JFK  432.791704         7.655012
# 26             MIA                LGA  243.173428         7.102515
# 27             OAK                EWR  566.234921        11.998450
# 28             OAK                JFK  550.595470        10.820000
# 29             OAK                LGA  698.285556        14.039015
# 30             ORD                EWR  271.779475         6.981141
# 31             ORD                JFK  462.100217         7.225983
# 32             ORD                LGA  191.740289         7.072959
# 33             PHL                EWR  397.856072         7.689727
# 34             PHL                JFK  344.472884         6.146404
# 35             PHL                LGA  319.525041         7.228287
# 36             SFO                EWR  525.368755         9.844264
# 37             SFO                JFK  441.833689        10.237381
# 38             SFO                LGA  540.555865        10.128277

# %%
alt.Chart(aggregated_transfer_ny_df).mark_point().encode(
    y=alt.Y('totalFare', title='Average Total Fare'),
    x='parsed_duration',
    color='destinationAirport',
    facet=alt.Facet('startingAirport:N', columns=5)
).properties(
    width=100,
    height=100,
    title='Travel Duration to Average Total Fare (Transfer flights to NYC)'
)
# Out:
# alt.Chart(...)

# %%
# Plot to see the relationship between travel duration and total fair flying to
# different airports around San Francisco
alt.Chart(aggregated_sf_df).mark_point().encode(
    y=alt.Y('totalFare', title='Average Total Fare'),
    x='parsed_duration',
    color='destinationAirport',
    facet=alt.Facet('startingAirport:N', columns=4)
).properties(
    width=100,
    height=100,
    title='Travel Duration to Average Total Fare (All flights to SF)'
)
# Out:
# alt.Chart(...)

# %%
# Direct Flight to airports near San Francisco
aggregated_direct_sf_df = sf_df[sf_df['isNonStop'] == True].groupby(
    by=['startingAirport', 'destinationAirport']
    )[['totalFare', 'parsed_duration']].mean().reset_index()
aggregated_direct_sf_df
# Out:
#    startingAirport destinationAirport   totalFare  parsed_duration
# 0              ATL                SFO  562.246821         5.226041
# 1              BOS                SFO  454.970256         6.772966
# 2              CLT                SFO  624.330142         5.633002
# 3              DEN                OAK  125.290864         2.618069
# 4              DEN                SFO  302.294133         2.742472
# 5              DFW                SFO  421.346723         3.893743
# 6              DTW                OAK  145.590000         4.933333
# 7              DTW                SFO  575.072728         5.127699
# 8              EWR                SFO  420.816529         6.299949
# 9              IAD                SFO  558.373066         5.932387
# 10             JFK                SFO  431.695438         6.557055
# 11             LAX                OAK  161.627002         1.333939
# 12             LAX                SFO  181.346362         1.445967
# 13             MIA                SFO  578.008410         6.244540
# 14             ORD                SFO  488.785711         4.666765
# 15             PHL                OAK  194.537368         5.840486
# 16             PHL                SFO  579.955681         6.159152

# %%
alt.Chart(aggregated_direct_sf_df).mark_point().encode(
    y=alt.Y('totalFare', title='Average Total Fare'),
    x='parsed_duration',
    color='destinationAirport',
    facet=alt.Facet('startingAirport:N', columns=5)
).properties(
    width=100,
    height=100,
    title='Travel Duration to Average Total Fare (Direct flights to SF)'
)
# Out:
# alt.Chart(...)

# %%
# Non Direct flight
aggregated_transfer_sf_df = sf_df[sf_df['isNonStop'] == False].groupby(
    by=['startingAirport', 'destinationAirport']
    )[['totalFare', 'parsed_duration']].mean().reset_index()
aggregated_transfer_sf_df
# Out:
#    startingAirport destinationAirport   totalFare  parsed_duration
# 0              ATL                OAK  630.816023        12.152037
# 1              ATL                SFO  553.122021        10.851847
# 2              BOS                OAK  601.611038        12.810557
# 3              BOS                SFO  450.232771        11.013211
# 4              CLT                OAK  664.895833        12.809369
# 5              CLT                SFO  573.878701        10.592956
# 6              DEN                OAK  395.761771         8.051951
# 7              DEN                SFO  353.309395         6.966758
# 8              DFW                OAK  480.466269        10.988052
# 9              DFW                SFO  437.631093         8.477277
# 10             DTW                OAK  579.662085        12.351940
# 11             DTW                SFO  578.782745        10.284040
# 12             EWR                OAK  564.880467        12.588182
# 13             EWR                SFO  484.113156        10.492726
# 14             IAD                OAK  665.276289        13.698998
# 15             IAD                SFO  538.968325        10.853432
# 16             JFK                OAK  537.001404        11.093392
# 17             JFK                SFO  414.250737        11.435465
# 18             LAX                OAK  406.684924         9.135698
# 19             LAX                SFO  279.901890         7.547959
# 20             LGA                OAK  715.005921        14.349343
# 21             LGA                SFO  533.073169        10.817695
# 22             MIA                OAK  687.193471        13.982645
# 23             MIA                SFO  526.862911        11.986563
# 24             OAK                SFO  410.529886         7.471527
# 25             ORD                OAK  505.421250        10.672869
# 26             ORD                SFO  485.911563         9.442027
# 27             PHL                OAK  651.303813        13.581066
# 28             PHL                SFO  568.892997        10.904643
# 29             SFO                OAK  426.502131         7.191254

# %%
alt.Chart(aggregated_transfer_sf_df).mark_point().encode(
    y=alt.Y('totalFare', title='Average Total Fare'),
    x='parsed_duration',
    color='destinationAirport',
    facet=alt.Facet('startingAirport:N', columns=4)
).properties(
    width=100,
    height=100,
    title='Travel Duration to Average Total Fare (Transfer flights to SF)'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Inspecting the relationship between price and seat remaining

# %%
# Drop the column search date as one flight can be searched on different dates. Here we only want unique flights.
seats_remain_df = april_may_df.copy().drop(['searchDate'], axis=1).drop_duplicates()
seats_remain_df.head(5)
# Out:
#    flightDate startingAirport destinationAirport fareBasisCode travelDuration  \
# 0  2022-04-17             ATL                BOS      LA0NX0MC        PT2H29M
# 1  2022-04-17             ATL                BOS      LA0NX0MC        PT2H30M
# 2  2022-04-17             ATL                BOS      LA0NX0MC        PT2H30M
# 3  2022-04-17             ATL                BOS      LA0NX0MC        PT2H32M
# 4  2022-04-17             ATL                BOS      LA0NX0MC        PT2H34M
#
#    isBasicEconomy  isRefundable  isNonStop  totalFare  seatsRemaining  \
# 0           False         False       True      248.6               9
# 1           False         False       True      248.6               4
# 2           False         False       True      248.6               9
# 3           False         False       True      248.6               8
# 4           False         False       True      248.6               9
#
#    totalTravelDistance       segmentsDepartureTimeRaw segmentsAirlineCode  \
# 0                947.0  2022-04-17T12:57:00.000-04:00                  DL
# 1                947.0  2022-04-17T06:30:00.000-04:00                  DL
# 2                947.0  2022-04-17T11:35:00.000-04:00                  DL
# 3                947.0  2022-04-17T13:59:00.000-04:00                  DL
# 4                947.0  2022-04-17T09:59:00.000-04:00                  DL
#
#   segmentsCabinCode
# 0             coach
# 1             coach
# 2             coach
# 3             coach
# 4             coach

# %%
# Prepare columns used in groupby
all_columns = set(seats_remain_df.columns)
exclude_columns = set(['totalFare', 'seatsRemaining'])
all_columns
# Out:
# {'destinationAirport',
#  'fareBasisCode',
#  'flightDate',
#  'isBasicEconomy',
#  'isNonStop',
#  'isRefundable',
#  'seatsRemaining',
#  'segmentsAirlineCode',
#  'segmentsCabinCode',
#  'segmentsDepartureTimeRaw',
#  'startingAirport',
#  'totalFare',
#  'totalTravelDistance',
#  'travelDuration'}

# %%
# Group by all columns except total fare and seatsRemaining and count the 
# how many different number of seatsRemaining in each group
seats_count_df = seats_remain_df.groupby(by=list(all_columns - exclude_columns))['seatsRemaining'].count().reset_index()
print(max(seats_count_df['seatsRemaining']))
# Out:
# 16

# %%
# Check details of flights that have maximum number of different seatsRemaining
seats_count_df[seats_count_df['seatsRemaining'] == 16]
# Out:
#            segmentsCabinCode  isNonStop segmentsAirlineCode  \
# 1551556         coach||coach      False              UA||AS
# 1566079         coach||coach      False              UA||DL
# 1566443         coach||coach      False              UA||DL
# 1567882         coach||coach      False              UA||DL
# 2039810  coach||coach||coach      False          UA||AS||AS
# 2039853  coach||coach||coach      False          UA||AS||AS
# 2043658  coach||coach||coach      False          UA||DL||DL
# 2043659  coach||coach||coach      False          UA||DL||DL
# 2056062  coach||coach||coach      False          UA||UA||DL
# 2059990  coach||coach||coach      False          UA||UA||DL
#
#         destinationAirport  totalTravelDistance  \
# 1551556                SFO               1242.0
# 1566079                JFK               2501.0
# 1566443                JFK               2794.0
# 1567882                LGA                710.0
# 2039810                OAK               3115.0
# 2039853                OAK               3115.0
# 2043658                OAK               3140.0
# 2043659                OAK               3140.0
# 2056062                OAK               2110.0
# 2059990                OAK               2637.0
#
#                                                                             segmentsDepartureTimeRaw  \
# 1551556                                 2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 1566079                                 2022-05-11T23:50:00.000-06:00||2022-05-12T11:41:00.000-04:00
# 1566443                                 2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 1567882                                 2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 2039810  2022-05-09T11:00:00.000-04:00||2022-05-09T15:12:00.000-05:00||2022-05-09T20:39:00.000-07:00
# 2039853  2022-05-14T06:30:00.000-04:00||2022-05-14T09:00:00.000-05:00||2022-05-14T14:03:00.000-07:00
# 2043658  2022-05-26T07:00:00.000-04:00||2022-05-26T15:30:00.000-05:00||2022-05-26T18:20:00.000-07:00
# 2043659  2022-05-26T09:50:00.000-04:00||2022-05-26T15:30:00.000-05:00||2022-05-26T18:20:00.000-07:00
# 2056062  2022-05-07T16:55:00.000-04:00||2022-05-07T19:20:00.000-06:00||2022-05-07T22:51:00.000-06:00
# 2059990  2022-05-07T07:02:00.000-04:00||2022-05-07T10:04:00.000-05:00||2022-05-07T16:30:00.000-07:00
#
#         startingAirport fareBasisCode  isRefundable travelDuration  \
# 1551556             DEN      QAA0OKEN         False        PT5H22M
# 1566079             DEN      QAA3AKEN         False       PT12H37M
# 1566443             DEN      QAA3AKEN         False       PT12H33M
# 1567882             IAD      QAA0OFEN         False         PT5H8M
# 2039810             LGA      QAA0OHEN         False       PT14H43M
# 2039853             LGA      QAA0OHEN         False       PT12H38M
# 2043658             LGA      QAA0OKEN         False       PT15H37M
# 2043659             LGA      QAA0OKEN         False       PT12H47M
# 2056062             DTW      QAA0OFEN         False        PT9H55M
# 2059990             CLT      QAA0AFEN         False       PT13H48M
#
#          isBasicEconomy  flightDate  seatsRemaining
# 1551556           False  2022-05-07              16
# 1566079           False  2022-05-11              16
# 1566443           False  2022-05-19              16
# 1567882           False  2022-05-08              16
# 2039810           False  2022-05-09              16
# 2039853           False  2022-05-14              16
# 2043658           False  2022-05-26              16
# 2043659           False  2022-05-26              16
# 2056062           False  2022-05-07              16
# 2059990           False  2022-05-07              16

# %%
# From original dataframe filter out the flight 1
flight_1 = seats_remain_df[(seats_remain_df['flightDate'] == '2022-05-07') & 
                        (seats_remain_df['startingAirport'] == 'DEN') & 
                        (seats_remain_df['destinationAirport'] == 'SFO') &
                        (seats_remain_df['isNonStop'] == False) &
                        (seats_remain_df['segmentsDepartureTimeRaw'] == 
                         '2022-05-07T13:26:00.000-06:00||' +
                          '2022-05-07T15:45:00.000-07:00') & 
                        (seats_remain_df['travelDuration'] == 'PT5H22M') &
                        (seats_remain_df['segmentsAirlineCode'] == 'UA||AS') & 
                        (seats_remain_df['fareBasisCode'] == 'QAA0OKEN')]
flight_1
# Out:
#          flightDate startingAirport destinationAirport fareBasisCode  \
# 261943   2022-05-07             DEN                SFO      QAA0OKEN
# 649176   2022-05-07             DEN                SFO      QAA0OKEN
# 1023079  2022-05-07             DEN                SFO      QAA0OKEN
# 2046395  2022-05-07             DEN                SFO      QAA0OKEN
# 2713419  2022-05-07             DEN                SFO      QAA0OKEN
# 2938904  2022-05-07             DEN                SFO      QAA0OKEN
# 3254231  2022-05-07             DEN                SFO      QAA0OKEN
# 3543684  2022-05-07             DEN                SFO      QAA0OKEN
# 3840249  2022-05-07             DEN                SFO      QAA0OKEN
# 4128330  2022-05-07             DEN                SFO      QAA0OKEN
# 4406920  2022-05-07             DEN                SFO      QAA0OKEN
# 4682592  2022-05-07             DEN                SFO      QAA0OKEN
# 4950073  2022-05-07             DEN                SFO      QAA0OKEN
# 5205650  2022-05-07             DEN                SFO      QAA0OKEN
# 5450493  2022-05-07             DEN                SFO      QAA0OKEN
# 5909670  2022-05-07             DEN                SFO      QAA0OKEN
#
#         travelDuration  isBasicEconomy  isRefundable  isNonStop  totalFare  \
# 261943         PT5H22M           False         False      False     421.60
# 649176         PT5H22M           False         False      False     421.60
# 1023079        PT5H22M           False         False      False     421.60
# 2046395        PT5H22M           False         False      False     451.60
# 2713419        PT5H22M           False         False      False     426.60
# 2938904        PT5H22M           False         False      False     371.60
# 3254231        PT5H22M           False         False      False     347.98
# 3543684        PT5H22M           False         False      False     430.60
# 3840249        PT5H22M           False         False      False     436.59
# 4128330        PT5H22M           False         False      False     451.60
# 4406920        PT5H22M           False         False      False     451.60
# 4682592        PT5H22M           False         False      False     491.60
# 4950073        PT5H22M           False         False      False     477.59
# 5205650        PT5H22M           False         False      False     641.60
# 5450493        PT5H22M           False         False      False     401.60
# 5909670        PT5H22M           False         False      False     422.60
#
#          seatsRemaining  totalTravelDistance  \
# 261943                1               1242.0
# 649176                2               1242.0
# 1023079               3               1242.0
# 2046395               4               1242.0
# 2713419               3               1242.0
# 2938904               6               1242.0
# 3254231               1               1242.0
# 3543684               1               1242.0
# 3840249               1               1242.0
# 4128330               2               1242.0
# 4406920               3               1242.0
# 4682592               1               1242.0
# 4950073               1               1242.0
# 5205650               7               1242.0
# 5450493               2               1242.0
# 5909670               2               1242.0
#
#                                              segmentsDepartureTimeRaw  \
# 261943   2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 649176   2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 1023079  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 2046395  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 2713419  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 2938904  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 3254231  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 3543684  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 3840249  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 4128330  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 4406920  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 4682592  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 4950073  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 5205650  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 5450493  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
# 5909670  2022-05-07T13:26:00.000-06:00||2022-05-07T15:45:00.000-07:00
#
#         segmentsAirlineCode segmentsCabinCode
# 261943               UA||AS      coach||coach
# 649176               UA||AS      coach||coach
# 1023079              UA||AS      coach||coach
# 2046395              UA||AS      coach||coach
# 2713419              UA||AS      coach||coach
# 2938904              UA||AS      coach||coach
# 3254231              UA||AS      coach||coach
# 3543684              UA||AS      coach||coach
# 3840249              UA||AS      coach||coach
# 4128330              UA||AS      coach||coach
# 4406920              UA||AS      coach||coach
# 4682592              UA||AS      coach||coach
# 4950073              UA||AS      coach||coach
# 5205650              UA||AS      coach||coach
# 5450493              UA||AS      coach||coach
# 5909670              UA||AS      coach||coach

# %%
# Plot to see the avergae price for each number of seats remaining for flight 1
alt.Chart(flight_1).mark_point().encode(
    y='mean(totalFare)',
    x='seatsRemaining',
).properties(
    title='Seats Remaining to Average Prices (Flight 1)'
)
# Out:
# alt.Chart(...)

# %%
# From original dataframe filter out the flight 2
flight_2 = seats_remain_df[
    (seats_remain_df['flightDate'] == '2022-05-19') & 
    (seats_remain_df['startingAirport'] == 'DEN') & 
    (seats_remain_df['destinationAirport'] == 'JFK') &
    (seats_remain_df['isNonStop'] == False) &
    (seats_remain_df['segmentsDepartureTimeRaw'] == 
     '2022-05-19T08:26:00.000-06:00||' + 
     '2022-05-19T19:58:00.000-04:00') & 
     (seats_remain_df['travelDuration'] == 'PT12H33M') &
     (seats_remain_df['segmentsAirlineCode'] == 'UA||DL') & 
     (seats_remain_df['fareBasisCode'] == 'QAA3AKEN')]
flight_2
# Out:
#          flightDate startingAirport destinationAirport fareBasisCode  \
# 370738   2022-05-19             DEN                JFK      QAA3AKEN
# 756046   2022-05-19             DEN                JFK      QAA3AKEN
# 1485430  2022-05-19             DEN                JFK      QAA3AKEN
# 1811956  2022-05-19             DEN                JFK      QAA3AKEN
# 2152841  2022-05-19             DEN                JFK      QAA3AKEN
# 2486586  2022-05-19             DEN                JFK      QAA3AKEN
# 2820448  2022-05-19             DEN                JFK      QAA3AKEN
# 3359105  2022-05-19             DEN                JFK      QAA3AKEN
# 3652224  2022-05-19             DEN                JFK      QAA3AKEN
# 3948453  2022-05-19             DEN                JFK      QAA3AKEN
# 4236644  2022-05-19             DEN                JFK      QAA3AKEN
# 4515899  2022-05-19             DEN                JFK      QAA3AKEN
# 5060143  2022-05-19             DEN                JFK      QAA3AKEN
# 5314886  2022-05-19             DEN                JFK      QAA3AKEN
# 5561001  2022-05-19             DEN                JFK      QAA3AKEN
# 5795879  2022-05-19             DEN                JFK      QAA3AKEN
#
#         travelDuration  isBasicEconomy  isRefundable  isNonStop  totalFare  \
# 370738        PT12H33M           False         False      False     547.20
# 756046        PT12H33M           False         False      False     547.20
# 1485430       PT12H33M           False         False      False     521.21
# 1811956       PT12H33M           False         False      False     521.21
# 2152841       PT12H33M           False         False      False     521.21
# 2486586       PT12H33M           False         False      False     521.21
# 2820448       PT12H33M           False         False      False     521.21
# 3359105       PT12H33M           False         False      False     521.21
# 3652224       PT12H33M           False         False      False     531.20
# 3948453       PT12H33M           False         False      False     557.21
# 4236644       PT12H33M           False         False      False     557.21
# 4515899       PT12H33M           False         False      False     561.21
# 5060143       PT12H33M           False         False      False     561.21
# 5314886       PT12H33M           False         False      False     561.21
# 5561001       PT12H33M           False         False      False     557.21
# 5795879       PT12H33M           False         False      False     571.20
#
#          seatsRemaining  totalTravelDistance  \
# 370738                5               2794.0
# 756046                2               2794.0
# 1485430               6               2794.0
# 1811956               8               2794.0
# 2152841               9               2794.0
# 2486586               7               2794.0
# 2820448               3               2794.0
# 3359105               4               2794.0
# 3652224               4               2794.0
# 3948453               5               2794.0
# 4236644               4               2794.0
# 4515899               4               2794.0
# 5060143               7               2794.0
# 5314886               8               2794.0
# 5561001               7               2794.0
# 5795879               8               2794.0
#
#                                              segmentsDepartureTimeRaw  \
# 370738   2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 756046   2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 1485430  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 1811956  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 2152841  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 2486586  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 2820448  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 3359105  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 3652224  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 3948453  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 4236644  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 4515899  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 5060143  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 5314886  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 5561001  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
# 5795879  2022-05-19T08:26:00.000-06:00||2022-05-19T19:58:00.000-04:00
#
#         segmentsAirlineCode segmentsCabinCode
# 370738               UA||DL      coach||coach
# 756046               UA||DL      coach||coach
# 1485430              UA||DL      coach||coach
# 1811956              UA||DL      coach||coach
# 2152841              UA||DL      coach||coach
# 2486586              UA||DL      coach||coach
# 2820448              UA||DL      coach||coach
# 3359105              UA||DL      coach||coach
# 3652224              UA||DL      coach||coach
# 3948453              UA||DL      coach||coach
# 4236644              UA||DL      coach||coach
# 4515899              UA||DL      coach||coach
# 5060143              UA||DL      coach||coach
# 5314886              UA||DL      coach||coach
# 5561001              UA||DL      coach||coach
# 5795879              UA||DL      coach||coach

# %%
# Plot to see the avergae price for each number of seats remaining for flight 2
alt.Chart(flight_2).mark_point().encode(
    y='mean(totalFare)',
    x='seatsRemaining',
).properties(
    title='Seats Remaining to Average Prices (Flight 2)'
)
# Out:
# alt.Chart(...)

# %%
# From original dataframe filter out the flight 3
flight_3 = seats_remain_df[
    (seats_remain_df['flightDate'] == '2022-05-08') & 
    (seats_remain_df['startingAirport'] == 'IAD') & 
    (seats_remain_df['destinationAirport'] == 'LGA') &
    (seats_remain_df['isNonStop'] == False) &
    (seats_remain_df['segmentsDepartureTimeRaw'] == 
     '2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00') & 
    (seats_remain_df['travelDuration'] == 'PT5H8M') &
    (seats_remain_df['segmentsAirlineCode'] == 'UA||DL') & 
    (seats_remain_df['fareBasisCode'] == 'QAA0OFEN')]
flight_3
# Out:
#          flightDate startingAirport destinationAirport fareBasisCode  \
# 659373   2022-05-08             IAD                LGA      QAA0OFEN
# 1033442  2022-05-08             IAD                LGA      QAA0OFEN
# 1391207  2022-05-08             IAD                LGA      QAA0OFEN
# 1716639  2022-05-08             IAD                LGA      QAA0OFEN
# 2723796  2022-05-08             IAD                LGA      QAA0OFEN
# 2949584  2022-05-08             IAD                LGA      QAA0OFEN
# 3265000  2022-05-08             IAD                LGA      QAA0OFEN
# 3554301  2022-05-08             IAD                LGA      QAA0OFEN
# 3850824  2022-05-08             IAD                LGA      QAA0OFEN
# 4138903  2022-05-08             IAD                LGA      QAA0OFEN
# 4417557  2022-05-08             IAD                LGA      QAA0OFEN
# 4693343  2022-05-08             IAD                LGA      QAA0OFEN
# 4961456  2022-05-08             IAD                LGA      QAA0OFEN
# 5217316  2022-05-08             IAD                LGA      QAA0OFEN
# 5462942  2022-05-08             IAD                LGA      QAA0OFEN
# 5922262  2022-05-08             IAD                LGA      QAA0OFEN
#
#         travelDuration  isBasicEconomy  isRefundable  isNonStop  totalFare  \
# 659373          PT5H8M           False         False      False      461.6
# 1033442         PT5H8M           False         False      False      461.6
# 1391207         PT5H8M           False         False      False      461.6
# 1716639         PT5H8M           False         False      False      461.6
# 2723796         PT5H8M           False         False      False      461.6
# 2949584         PT5H8M           False         False      False      491.6
# 3265000         PT5H8M           False         False      False      491.6
# 3554301         PT5H8M           False         False      False      531.6
# 3850824         PT5H8M           False         False      False      531.6
# 4138903         PT5H8M           False         False      False      571.6
# 4417557         PT5H8M           False         False      False      571.6
# 4693343         PT5H8M           False         False      False      571.6
# 4961456         PT5H8M           False         False      False      571.6
# 5217316         PT5H8M           False         False      False      621.6
# 5462942         PT5H8M           False         False      False      621.6
# 5922262         PT5H8M           False         False      False      621.6
#
#          seatsRemaining  totalTravelDistance  \
# 659373                5                710.0
# 1033442               6                710.0
# 1391207               7                710.0
# 1716639               8                710.0
# 2723796               4                710.0
# 2949584               7                710.0
# 3265000               6                710.0
# 3554301               4                710.0
# 3850824               5                710.0
# 4138903               6                710.0
# 4417557               7                710.0
# 4693343               5                710.0
# 4961456               4                710.0
# 5217316               5                710.0
# 5462942               8                710.0
# 5922262               6                710.0
#
#                                              segmentsDepartureTimeRaw  \
# 659373   2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 1033442  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 1391207  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 1716639  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 2723796  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 2949584  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 3265000  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 3554301  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 3850824  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 4138903  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 4417557  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 4693343  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 4961456  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 5217316  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 5462942  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
# 5922262  2022-05-08T08:21:00.000-04:00||2022-05-08T11:52:00.000-04:00
#
#         segmentsAirlineCode segmentsCabinCode
# 659373               UA||DL      coach||coach
# 1033442              UA||DL      coach||coach
# 1391207              UA||DL      coach||coach
# 1716639              UA||DL      coach||coach
# 2723796              UA||DL      coach||coach
# 2949584              UA||DL      coach||coach
# 3265000              UA||DL      coach||coach
# 3554301              UA||DL      coach||coach
# 3850824              UA||DL      coach||coach
# 4138903              UA||DL      coach||coach
# 4417557              UA||DL      coach||coach
# 4693343              UA||DL      coach||coach
# 4961456              UA||DL      coach||coach
# 5217316              UA||DL      coach||coach
# 5462942              UA||DL      coach||coach
# 5922262              UA||DL      coach||coach

# %%
# Plot to see the avergae price for each number of seats remaining for flight 3
alt.Chart(flight_3).mark_point().encode(
    y='mean(totalFare)',
    x='seatsRemaining',
).properties(
    title='Seats Remaining to Average Prices (Flight 3)'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Get the data for the ful time duration to see a bigger picture of the data.

# %%
alltime_df = pd.read_csv('drive/My Drive/Data_Science_Big_Data_T11/Alltime_Data.csv')
alltime_df.tail()
# Out:
#           searchDate  flightDate  totalFare
# 82138748  2022-10-05  2022-11-12     224.60
# 82138749  2022-10-05  2022-11-12     228.59
# 82138750  2022-10-05  2022-11-12     251.60
# 82138751  2022-10-05  2022-11-12     251.60
# 82138752  2022-10-05  2022-11-12     268.60

# %%
alltime_df['flightDate'] = pd.to_datetime(alltime_df['flightDate'])

alldate_to_fare = pd.DataFrame(alltime_df.groupby('flightDate')['totalFare'].mean().reset_index())
searchalldate_to_fare = pd.DataFrame(alltime_df.groupby('searchDate')['totalFare'].mean().reset_index())

searchalldate_to_fare.head()
# Out:
#    searchDate   totalFare
# 0  2022-04-16  371.575580
# 1  2022-04-17  349.504482
# 2  2022-04-18  344.606550
# 3  2022-04-19  359.993897
# 4  2022-04-20  349.483219

# %% [markdown]
# # Exploratory Analysis

# %%
alltime_df.totalFare.describe()

# %%
alldate_to_fare.totalFare.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0af21c764742> in <module>
# ----> 1 alldate_to_fare.totalFare.describe()
#
# NameError: name 'alldate_to_fare' is not defined

# %%
searchalldate_to_fare.totalFare.describe()

# %%
interval = alt.selection_interval(encodings=['x'])

base = alt.Chart(alldate_to_fare).mark_line().encode(
    x='flightDate:T',
    y='totalFare:Q',
    tooltip=[
        alt.Tooltip('flightDate:T', title='Flight Date'),
        alt.Tooltip('totalFare:Q', title='Total Fare')
    ]
).properties(
    title = 'Daily Mean Flight Price from April to November'
)

chart = base.properties(
    width=800,
    height=300
).encode(
    x = alt.X('flightDate:T', scale=alt.Scale(domain=interval.ref()))
)

view = chart.properties(
    width=800,
    height=50,
    selection = interval
)

chart & view
# Out:
# alt.VConcatChart(...)

# %%
interval = alt.selection_interval(encodings=['x'])

search = alt.Chart(searchalldate_to_fare).mark_line().encode(
    x='searchDate:T',
    y='totalFare:Q',
    tooltip=[
        alt.Tooltip('searchDate:T', title='Search Date'),
        alt.Tooltip('totalFare:Q', title='Total Fare')
    ]
).properties(
    title = 'Daily Average for Searching Flight Price from April to November'
)

chart = search.properties(
    width=800,
    height=300
).encode(
    x = alt.X('searchDate:T', scale=alt.Scale(domain=interval.ref()))
)

view = chart.properties(
    width=800,
    height=50,
    selection = interval
)

chart & view
# Out:
# alt.VConcatChart(...)

# %%
base = alt.Chart(alldate_to_fare).mark_bar().encode(
    x = alt.X('flightDate:O', timeUnit='month'),
    y = 'mean(totalFare):Q'
)
search = alt.Chart(searchalldate_to_fare).mark_bar(color='red', opacity=0.5).encode(
    x = alt.X('searchDate:O', timeUnit='month'),
    y = 'mean(totalFare):Q'
).properties(
    title = 'Mean Flight Price by month'
)

(base + search).properties(title='Average Price by Month')
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(alldate_to_fare).mark_rect().encode(
    x = alt.X('flightDate:O', timeUnit = 'date'),
    y = alt.Y('flightDate:O', timeUnit = 'month'),
    color = alt.Color('mean(totalFare):Q', scale=alt.Scale(scheme='greens')),
    tooltip=[
        alt.Tooltip('flightDate:T', title='Flight Date'),
        alt.Tooltip('totalFare:Q', title='Total Fare')
    ]
).properties(
    title = 'Mean Flight Price by every days in months'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(alldate_to_fare).mark_rect().encode(
    x = alt.X('flightDate:O', timeUnit = 'week'),
    y = alt.Y('flightDate:O', timeUnit = 'month'),
    color = alt.Color('mean(totalFare):Q', scale=alt.Scale(scheme='greens')),
    tooltip=[
        alt.Tooltip('flightDate:T', title='Flight Date'),
        alt.Tooltip('totalFare:Q', title='Total Fare')
    ]
).properties(
    title = 'Mean Flight Price by weeks from April to November'
)
# Out:
# alt.Chart(...)
